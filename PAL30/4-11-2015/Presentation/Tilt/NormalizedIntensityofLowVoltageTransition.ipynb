# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import glob
from scipy.optimize import curve_fit
from matplotlib import rcParams
rcParams['axes.labelsize'] = 32
rcParams['xtick.labelsize'] = 30
rcParams['ytick.labelsize'] = 30
rcParams['legend.fontsize'] = 25
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Computer Modern Roman']
rcParams['text.usetex'] = True
rcParams['figure.figsize'] = (12.0, 6.0)

# %%
pol89 = np.loadtxt('feature1-pol89')
pol90 = np.loadtxt('feature1-pol90')
pol91 = np.loadtxt('feature1-pol91')

# %%
plt.errorbar(pol89[0]/np.pi*180.,pol89[1],yerr=pol89[2],fmt='.',label=r'Crossed 89.1 $^o$')
plt.errorbar(pol90[0]/np.pi*180.,pol90[1],yerr=pol90[2],fmt='.',label=r'Crossed 90 $^o$')
plt.errorbar(pol91[0]/np.pi*180.,pol91[1],yerr=pol91[2],fmt='.',label=r'Crossed 91.9 $^o$')


plt.xlabel(r'Degrees $^o$')
plt.ylabel(r'Intensity $(Arb. Units)$')
plt.legend(loc='best')
plt.tight_layout(pad=.4)

plt.savefig("tiltevidence-film4-t95.png")
